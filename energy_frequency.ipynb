# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.4 kB 682.7 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 809.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/43.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/43.7 MB 10.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.4/43.7 MB 14.3 MB/s eta 0:00:03
#    -- ------------------------------------- 2.6/43.7 MB 18.2 MB/s eta 0:00:03
#    --- ------------------------------------ 3.6/43.7 MB 19.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.6/43.7 MB 19.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.8/43.7 MB 20.7 MB/s eta 0:00:02
#    ------ --------------------------------- 6.8/43.7 MB 20.7 MB/s eta 0:00:02
#    ------- -------------------------------- 7.9/43.7 MB 21.0 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import h, k, c

print(h*4e9/k/1e-3)
print(h*10e9/k/1e-3)
# Out:
# 191.96972293464884
# 479.92430733662206
